# %% [markdown]
# <a href="https://colab.research.google.com/github/rafaelromwno/am-t4-s1a2026/blob/main/aula-7/NeuralizadorCredit0423.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pipeline | Carregamento e Detecção de Anomalias [Fase 1 - census_data]

# %% [markdown]
# ## Importar dados do Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Bibliotecas de Python

# %%
# !pip -q install plotly
# !pip -q install yellowbrick

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as pl
import plotly.express as px

# %% [markdown]
# ## Carregar Digest de base_credit

# %%
import pickle

# %%
with open('/content/drive/MyDrive/Documentos/profissional-academico/FATEC/CICLOS/ciclo-v/machine-learning/credit.pkt', mode = 'rb') as f:
   X_credit_treinamento, Y_credit_treinamento, X_credit_teste, Y_credit_teste = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_12576/100158722.py in <cell line: 0>()
#       1 with open('/content/drive/MyDrive/Documentos/profissional-academico/FATEC/CICLOS/ciclo-v/machine-learning/credit.pkt', mode = 'rb') as f:
# ----> 2    X_credit_treinamento, Y_credit_treinamento, X_credit_teste, Y_credit_teste = pickle.load(f)
#
# NameError: name 'pickle' is not defined

# %%
X_credit_treinamento.shape, Y_credit_treinamento.shape

# %%
X_credit_teste.shape, Y_credit_teste.shape

# %%
from sklearn.naive_bayes import GaussianNB

# %%
naive_credit_data = GaussianNB()
naive_credit_data.fit(X_credit_treinamento, Y_credit_treinamento)
