# %% [markdown]
# <a href="https://colab.research.google.com/github/rafaelromwno/am-t4-s1a2026/blob/main/aula-1/aula2403_am4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introdução de Python

# %%
a=2
b=3
print("A soma é: ", a+b)
# Out:
# A soma é:  5

# %% [markdown]
# ## Segunda camada

# %%
c=4
d=5
print("A multiplicação é ", c*d)
# Out:
# A multiplicação é  20

# %% [markdown]
# # Bibliotecas e Funções de Python

# %%
import math

def equacao2grau(a, b, c):
  delta = b**2 - 4*a*c

  if(delta < 0):
    return 'Número sem raiz', delta

  x1 = (-b + math.sqrt(delta)) / (2*a)
  x2 = (-b - math.sqrt(delta)) / (2*a)

  return x1, x2

# %% [markdown]
# ## Testes de Funções Matemáticas

# %%
result = equacao2grau(1, -3, 2)

print(result)
# Out:
# (2.0, 1.0)

# %%
import random

for i in range(5):
  a = random.randint(-5, 1)
  while a == 0:
    a = random.randint(-5, 1)
  b = random.randint(-10, 10)
  c = random.randint(-10, 10)

  result += equacao2grau(a, b, c)

# %%
print(result)
# Out:
# (2.0, 1.0, -1.7071067811865475, -0.2928932188134524, 0.3596117967977924, 1.3903882032022077, -1.8507810593582121, 1.3507810593582121, -2.186140661634507, 0.6861406616345072, -2.0, 0.6666666666666666, -0.4, 2.0, 0.5825756949558398, -8.582575694955839, -0.0, 4.5, -2.341640786499874, 0.3416407864998739, 'Número sem raiz', -76, 5.0, -1.0)
